# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit
# Out:
# ...
#      -------------------------------------- 10.5/10.5 MB 364.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 14.6/14.6 MB 459.0 kB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\ajou\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\ajou\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 7.2/7.2 MB 2.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 944.1/944.1 KB 2.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 KB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 1.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('chess_games.csv')

# %%
df.describe()
# Out:
#             game_id         turns  white_rating  black_rating  opening_moves
# count  20058.000000  20058.000000  20058.000000  20058.000000   20058.000000
# mean   10029.500000     60.465999   1596.631868   1588.831987       4.816981
# std     5790.390185     33.570585    291.253376    291.036126       2.797152
# min        1.000000      1.000000    784.000000    789.000000       1.000000
# 25%     5015.250000     37.000000   1398.000000   1391.000000       3.000000
# 50%    10029.500000     55.000000   1567.000000   1562.000000       4.000000
# 75%    15043.750000     79.000000   1793.000000   1784.000000       6.000000
# max    20058.000000    349.000000   2700.000000   2723.000000      28.000000

# %%
df.describe(include='all')
# Out:
#              game_id  rated         turns victory_status winner  \
# count   20058.000000  20058  20058.000000          20058  20058
# unique           NaN      2           NaN              4      3
# top              NaN   True           NaN         Resign  White
# freq             NaN  16155           NaN          11147  10001
# mean    10029.500000    NaN     60.465999            NaN    NaN
# std      5790.390185    NaN     33.570585            NaN    NaN
# min         1.000000    NaN      1.000000            NaN    NaN
# 25%      5015.250000    NaN     37.000000            NaN    NaN
# 50%     10029.500000    NaN     55.000000            NaN    NaN
# 75%     15043.750000    NaN     79.000000            NaN    NaN
# max     20058.000000    NaN    349.000000            NaN    NaN
#
#        time_increment white_id  white_rating black_id  black_rating  moves  \
# count           20058    20058  20058.000000    20058  20058.000000  20058
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game_id            20058 non-null  int64
#  1   rated              20058 non-null  bool
#  2   turns              20058 non-null  int64
#  3   victory_status     20058 non-null  object
#  4   winner             20058 non-null  object
#  5   time_increment     20058 non-null  object
#  6   white_id           20058 non-null  object
#  7   white_rating       20058 non-null  int64
#  8   black_id           20058 non-null  object
#  9   black_rating       20058 non-null  int64
#  10  moves              20058 non-null  object
#  11  opening_code       20058 non-null  object
#  12  opening_moves      20058 non-null  int64
#  13  opening_fullname   20058 non-null  object
#  14  opening_shortname  20058 non-null  object
#  15  opening_response   1207 non-null   object
# ...

# %%
df['opening_code'].count()
# Out:
# 20058

# %%
game_id
white_id
black_id
opening_code

# %%
df_white = pd.DataFrame(df['white_id'])
df_white.head()
# Out:
#         white_id
# 0       bourgris
# 1           a-00
# 2         ischia
# 3  daniamurashov
# 4      nik221107

# %%
df_white["white_rating"] = df.index.map(df["white_rating"])

# %%
df["white_rating"]
# Out:
# 0        1500
# 1        1322
# 2        1496
# 3        1439
# 4        1523
#          ...
# 20053    1691
# 20054    1233
# 20055    1219
# 20056    1360
# 20057    1235
# Name: white_rating, Length: 20058, dtype: int64

# %%
df_white.set_index("white_id", inplace=True)
df_white
# Out:
#               white_rating
# white_id
# bourgris
# a-00
# ischia
# daniamurashov
# nik221107
# ...                    ...
# belcolt
# jamboger
# jamboger
# marcodisogno
# jamboger
#
# [20058 rows x 1 columns]

# %%
df_white
# Out:
#                white_rating
# white_id
# bourgris               1500
# a-00                   1322
# ischia                 1496
# daniamurashov          1439
# nik221107              1523
# ...                     ...
# belcolt                1691
# jamboger               1233
# jamboger               1219
# marcodisogno           1360
# jamboger               1235
#
# [20058 rows x 1 columns]

# %%
df_black = pd.DataFrame(df['black_id'])
df_black.head()
# Out:
#        black_id
# 0          a-00
# 1     skinnerua
# 2          a-00
# 3  adivanov2009
# 4  adivanov2009

# %%
df_black["black_rating"] = df.index.map(df["black_rating"])

# %%
df["black_rating"]
# Out:
# 0        1191
# 1        1261
# 2        1500
# 3        1454
# 4        1469
#          ...
# 20053    1220
# 20054    1196
# 20055    1286
# 20056    1227
# 20057    1339
# Name: black_rating, Length: 20058, dtype: int64

# %%
df_black.set_index("black_id", inplace=True)
df_black
# Out:
#                     black_rating
# black_id
# a-00                        1191
# skinnerua                   1261
# a-00                        1500
# adivanov2009                1454
# adivanov2009                1469
# ...                          ...
# jamboger                    1220
# farrukhasomiddinov          1196
# schaaksmurf3                1286
# jamboger                    1227
# ffbob                       1339
#
# [20058 rows x 1 columns]

# %%
df_black
# Out:
#                     black_rating
# black_id
# a-00                        1191
# skinnerua                   1261
# a-00                        1500
# adivanov2009                1454
# adivanov2009                1469
# ...                          ...
# jamboger                    1220
# farrukhasomiddinov          1196
# schaaksmurf3                1286
# jamboger                    1227
# ffbob                       1339
#
# [20058 rows x 1 columns]

# %%
df_op = pd.DataFrame(df['opening_code'])
df_op.head()
# Out:
#   opening_code
# 0          D10
# 1          B00
# 2          C20
# 3          D02
# 4          C41

# %%
df_op["opening_moves"] = df.index.map(df["opening_moves"])
df_op["opening_fullname"] = df.index.map(df["opening_fullname"])
df_op["opening_shortname"] = df.index.map(df["opening_shortname"])
df_op["opening_variation"] = df.index.map(df["opening_variation"])

# %%
df_op.head()
# Out:
#   opening_code  opening_moves                        opening_fullname  \
# 0          D10              5        Slav Defense: Exchange Variation
# 1          B00              4  Nimzowitsch Defense: Kennedy Variation
# 2          C20              3   King's Pawn Game: Leonardis Variation
# 3          D02              3  Queen's Pawn Game: Zukertort Variation
# 4          C41              5                        Philidor Defense
#
#      opening_shortname    opening_variation
# 0         Slav Defense   Exchange Variation
# 1  Nimzowitsch Defense    Kennedy Variation
# 2     King's Pawn Game  Leonardis Variation
# 3    Queen's Pawn Game  Zukertort Variation
# 4     Philidor Defense                  NaN

# %%
df_op.set_index("opening_code", inplace=True)
df_op.head()
# Out:
#               opening_moves                        opening_fullname  \
# opening_code
# D10                       5        Slav Defense: Exchange Variation
# B00                       4  Nimzowitsch Defense: Kennedy Variation
# C20                       3   King's Pawn Game: Leonardis Variation
# D02                       3  Queen's Pawn Game: Zukertort Variation
# C41                       5                        Philidor Defense
#
#                 opening_shortname    opening_variation
# opening_code
# D10                  Slav Defense   Exchange Variation
# B00           Nimzowitsch Defense    Kennedy Variation
# C20              King's Pawn Game  Leonardis Variation
# D02             Queen's Pawn Game  Zukertort Variation
# C41              Philidor Defense                  NaN
